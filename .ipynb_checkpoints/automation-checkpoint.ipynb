# %%
import pymysql
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://maria_dev:maria_dev@localhost:1080/datebase')
engine.connect()

# print(engine.execute("select 1").scalar())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     324         else:
# --> 325             self.connect()
#     326
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     597
# --> 598             self._get_server_information()
#     599             self._request_authentication()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _get_server_information(self)
#     974         i = 0
# --> 975         packet = self._read_packet()
#     976         data = packet.get_all_data()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     656         while True:
# --> 657             packet_header = self._read_bytes(4)
#     658             #if DEBUG: dump_packet(packet_header)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     706             raise err.OperationalError(
# --> 707                 CR.CR_SERVER_LOST, "Lost connection to MySQL server during query")
#     708         return data
#
# OperationalError: (2013, 'Lost connection to MySQL server during query')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-11-d5ee34952a09> in <module>
#       2 from sqlalchemy import create_engine
#       3 engine = create_engine('mysql+pymysql://maria_dev:maria_dev@localhost:1080/datebase')
# ----> 4 engine.connect()
#       5
#       6 # print(engine.execute("select 1").scalar())
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, **kwargs)
#    2204         """
#    2205
# -> 2206         return self._connection_cls(self, **kwargs)
#    2207
#    2208     @util.deprecated(
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    2304         """
#    2305         return self._wrap_pool_connect(
# -> 2306             self.pool.unique_connection, _connection
#    2307         )
#    2308
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2277             if connection is None:
#    2278                 Connection._handle_dbapi_exception_noconnection(
# -> 2279                     e, dialect, self
#    2280                 )
#    2281             else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1542             util.raise_from_cause(newraise, exc_info)
#    1543         elif should_wrap:
# -> 1544             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1545         else:
#    1546             util.reraise(*exc_info)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2273         dialect = self.dialect
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#    2277             if connection is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     301
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#     305     def _create_connection(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     479
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#     483     def create_connect_args(self, url):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     323             self._sock = None
#     324         else:
# --> 325             self.connect()
#     326
#     327     def _create_ssl_ctx(self, sslp):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     596             self._next_seq_id = 0
#     597
# --> 598             self._get_server_information()
#     599             self._request_authentication()
#     600
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _get_server_information(self)
#     973     def _get_server_information(self):
#     974         i = 0
# --> 975         packet = self._read_packet()
#     976         data = packet.get_all_data()
#     977
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     655         buff = b''
#     656         while True:
# --> 657             packet_header = self._read_bytes(4)
#     658             #if DEBUG: dump_packet(packet_header)
#     659
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_bytes(self, num_bytes)
#     705             self._force_close()
#     706             raise err.OperationalError(
# --> 707                 CR.CR_SERVER_LOST, "Lost connection to MySQL server during query")
#     708         return data
#     709
#
# OperationalError: (pymysql.err.OperationalError) (2013, 'Lost connection to MySQL server during query')
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
from bs4 import BeautifulSoup
from time import sleep
import requests
import pandas as pd
import csv
import datetime
import re

URL = 'http://finance.naver.com/marketindex/exchangeDailyQuote.nhn?marketindexCd=FX_'
keys = ['USDKRW', 'JPYKRW', 'EURKRW', 'CNYKRW', 'CADKRW', 'AUDKRW']

def clean_text(text):
    cleaned_text = re.sub(',', '', text)
    return cleaned_text

def country():
    country_name_list = []
    for key in keys:
        country_url = 'https://finance.naver.com/marketindex/exchangeDetail.nhn?marketindexCd=FX_'
        tempUrl = country_url + key
        req = requests.get(tempUrl)
        soup = BeautifulSoup(req.text, "html.parser")
        country_names = soup.select('#container > div.h_company > h2 ')
        for country_name in country_names:
#             print(country_name.text)
            country_name = country_name.text.strip()
            if country_name == '미국':
                country_name = 'USA'
            if country_name == '일본':
                country_name = 'JAPAN'
            if country_name == '유럽연합':
                country_name = 'EUROPE'
            if country_name == '중국':
                country_name = 'CHINA'
            if country_name == '캐나다':
                country_name = 'CANADA'
            if country_name == '호주':
                country_name = 'AUSTRALIA' 
            country_name_list.append(country_name)
    return country_name_list

def usd_get_one_data(country_name):
    usd_url = URL + keys[0] + '&page=1'
    req = requests.get(usd_url)
    soup = BeautifulSoup(req.text, "html.parser")
    sleep(1)
    usd_new_list = []
    tr_list = soup.select('body > div > table > tbody > tr')
    for tr in tr_list:
        usd_date = tr.find('td', {'class' : 'date'}).text
        usd_exchange = tr.find('td', {'class' : 'num'}).text
        usd_exchange = clean_text(usd_exchange)
        for usd_buy_cash in tr.select('td:nth-child(4)'):
            usd_buy_cash = clean_text(usd_buy_cash.text)
        for usd_sell_cash in tr.select('td:nth-child(5)'):
            usd_sell_cash = clean_text(usd_sell_cash.text)
        for usd_send_money in tr.select('td:nth-child(6)'):
            usd_send_money = clean_text(usd_send_money.text)
        for usd_get_money in tr.select('td:nth-child(7)'):
            usd_get_money = clean_text(usd_get_money.text)
        for usd_buy_tc in tr.select('td:nth-child(8)'):
            usd_buy_tc = clean_text(usd_buy_tc.text.strip())
        for usd_sell_check in tr.select('td:nth-child(9)'):
            usd_sell_check = clean_text(usd_sell_check.text.strip())
        usd_new_list.append([country_name, usd_date, usd_exchange, usd_buy_cash, usd_sell_cash, usd_send_money, usd_get_money, usd_buy_tc, usd_sell_check])
        
    return usd_new_list[0]

def jpy_get_one_data(country_name):
    jpy_url = URL + keys[1] + '&page1'
    req = requests.get(jpy_url)
    soup = BeautifulSoup(req.text, "html.parser")
    sleep(1)
    jpy_new_list = []
    tr_list = soup.select('body > div > table > tbody > tr')
    for tr in tr_list:
        jpy_date = tr.find('td', {'class' : 'date'}).text
        jpy_exchange = tr.find('td', {'class' : 'num'}).text
        jpy_exchange = clean_text(jpy_exchange)
        for jpy_buy_cash in tr.select('td:nth-child(4)'):
            jpy_buy_cash = clean_text(jpy_buy_cash.text)
        for jpy_sell_cash in tr.select('td:nth-child(5)'):
            jpy_sell_cash = clean_text(jpy_sell_cash.text)
        for jpy_send_money in tr.select('td:nth-child(6)'):
            jpy_send_money = clean_text(jpy_send_money.text)
        for jpy_get_money in tr.select('td:nth-child(7)'):
            jpy_get_money = clean_text(jpy_get_money.text)
        for jpy_buy_tc in tr.select('td:nth-child(8)'):
            jpy_buy_tc = clean_text(jpy_buy_tc.text.strip())
        for jpy_sell_check in tr.select('td:nth-child(9)'):
            jpy_sell_check = clean_text(jpy_sell_check.text.strip())
        jpy_new_list.append([country_name, jpy_date, jpy_exchange, jpy_buy_cash, jpy_sell_cash, jpy_send_money, jpy_get_money, jpy_buy_tc, jpy_sell_check])

    return jpy_new_list[0]

def eur_get_one_data(country_name):
    eur_url = URL + keys[2] + '&page1'
    req = requests.get(eur_url)
    soup = BeautifulSoup(req.text, "html.parser")
    sleep(1)
    eur_new_list = []
    tr_list = soup.select('body > div > table > tbody > tr')
    for tr in tr_list:
        eur_date = tr.find('td', {'class' : 'date'}).text
        eur_exchange = tr.find('td', {'class' : 'num'}).text
        eur_exchange = clean_text(eur_exchange)
        for eur_buy_cash in tr.select('td:nth-child(4)'):
            eur_buy_cash = clean_text(eur_buy_cash.text)
        for eur_sell_cash in tr.select('td:nth-child(5)'):
            eur_sell_cash = clean_text(eur_sell_cash.text)
        for eur_send_money in tr.select('td:nth-child(6)'):
            eur_send_money = clean_text(eur_send_money.text)
        for eur_get_money in tr.select('td:nth-child(7)'):
            eur_get_money = clean_text(eur_get_money.text)
        for eur_buy_tc in tr.select('td:nth-child(8)'):
            eur_buy_tc = clean_text(eur_buy_tc.text.strip())
        for eur_sell_check in tr.select('td:nth-child(9)'):
            eur_sell_check = clean_text(eur_sell_check.text.strip())
        eur_new_list.append([country_name, eur_date, eur_exchange, eur_buy_cash, eur_sell_cash, eur_send_money, eur_get_money, eur_buy_tc, eur_sell_check])

    return eur_new_list[0]

def cny_get_one_data(country_name):
    cny_url = URL + keys[3] + '&page1'
    req = requests.get(cny_url)
    soup = BeautifulSoup(req.text, "html.parser")
    sleep(1)
    cny_new_list = []
    tr_list = soup.select('body > div > table > tbody > tr')
    for tr in tr_list:
        cny_date = tr.find('td', {'class' : 'date'}).text
        cny_exchange = tr.find('td', {'class' : 'num'}).text
        cny_exchange = clean_text(cny_exchange)
        for cny_buy_cash in tr.select('td:nth-child(4)'):
            cny_buy_cash = clean_text(cny_buy_cash.text)
        for cny_sell_cash in tr.select('td:nth-child(5)'):
            cny_sell_cash = clean_text(cny_sell_cash.text)
        for cny_send_money in tr.select('td:nth-child(6)'):
            cny_send_money = clean_text(cny_send_money.text)
        for cny_get_money in tr.select('td:nth-child(7)'):
            cny_get_money = clean_text(cny_get_money.text)
        for cny_buy_tc in tr.select('td:nth-child(8)'):
            cny_buy_tc = clean_text(cny_buy_tc.text.strip())
        for cny_sell_check in tr.select('td:nth-child(9)'):
            cny_sell_check = clean_text(cny_sell_check.text.strip())
        cny_new_list.append([country_name, cny_date, cny_exchange, cny_buy_cash, cny_sell_cash, cny_send_money, cny_get_money, cny_buy_tc, cny_sell_check])

    return cny_new_list[0]

def cad_get_one_data(country_name):
    cad_url = URL + keys[4] + '&page1'
    req = requests.get(cad_url)
    soup = BeautifulSoup(req.text, "html.parser")
    sleep(1)
    cad_new_list = []
    tr_list = soup.select('body > div > table > tbody > tr')
    for tr in tr_list:
        cad_date = tr.find('td', {'class' : 'date'}).text
        cad_exchange = tr.find('td', {'class' : 'num'}).text
        cad_exchange = clean_text(cad_exchange)
        for cad_buy_cash in tr.select('td:nth-child(4)'):
            cad_buy_cash = clean_text(cad_buy_cash.text)
        for cad_sell_cash in tr.select('td:nth-child(5)'):
            cad_sell_cash = clean_text(cad_sell_cash.text)
        for cad_send_money in tr.select('td:nth-child(6)'):
            cad_send_money = clean_text(cad_send_money.text)
        for cad_get_money in tr.select('td:nth-child(7)'):
            cad_get_money = clean_text(cad_get_money.text)
        for cad_buy_tc in tr.select('td:nth-child(8)'):
            cad_buy_tc = clean_text(cad_buy_tc.text.strip())
        for cad_sell_check in tr.select('td:nth-child(9)'):
            cad_sell_check = clean_text(cad_sell_check.text.strip())
        cad_new_list.append([country_name, cad_date, cad_exchange, cad_buy_cash, cad_sell_cash, cad_send_money, cad_get_money, cad_buy_tc, cad_sell_check])

    return cad_new_list[0]

def aud_get_one_data(country_name):
    aud_url = URL + keys[5] + '&page1'
    req = requests.get(aud_url)
    soup = BeautifulSoup(req.text, "html.parser")
    sleep(1)
    aud_new_list = []
    tr_list = soup.select('body > div > table > tbody > tr')
    for tr in tr_list:
        aud_date = tr.find('td', {'class' : 'date'}).text
        aud_exchange = tr.find('td', {'class' : 'num'}).text
        aud_exchange = clean_text(aud_exchange)
        for aud_buy_cash in tr.select('td:nth-child(4)'):
            aud_buy_cash = clean_text(aud_buy_cash.text)
        for aud_sell_cash in tr.select('td:nth-child(5)'):
            aud_sell_cash = clean_text(aud_sell_cash.text)
        for aud_send_money in tr.select('td:nth-child(6)'):
            aud_send_money = clean_text(aud_send_money.text)
        for aud_get_money in tr.select('td:nth-child(7)'):
            aud_get_money = clean_text(aud_get_money.text)
        for aud_buy_tc in tr.select('td:nth-child(8)'):
            aud_buy_tc = clean_text(aud_buy_tc.text.strip())
        for aud_sell_check in tr.select('td:nth-child(9)'):
            aud_sell_check = clean_text(aud_sell_check.text.strip())
        aud_new_list.append([country_name, aud_date, aud_exchange, aud_buy_cash, aud_sell_cash, aud_send_money, aud_get_money, aud_buy_tc, aud_sell_check])

    return aud_new_list[0]

def toCSV_a(whole_list):
    dt = datetime.datetime.now()
    with open('exchange'+dt.strftime('%Y_%m_%d')+'.csv', 'w', encoding='utf-8', newline='') as file:
#     with open('exchange2019_12_02.csv', 'w', encoding='utf-8', newline='') as file:
        csvfile = csv.writer(file)
        csvfile.writerow(['country', 'date', 'exchange', 'buying_cash', 'selling_cash', 'sending_money', 'getting_money', 'buying_TC', 'selling_check'])
        csvfile.writerow(whole_list)
    file.close()
    
def toCSV_b(whole_list):
    dt = datetime.datetime.now()
    with open('exchange'+dt.strftime('%Y_%m_%d')+'.csv', 'a', encoding='utf-8', newline='') as file:
#     with open('exchange2019_12_02.csv', 'a', encoding='utf-8', newline='') as file:
        csvfile = csv.writer(file) 
        csvfile.writerow(whole_list)
    file.close()

if __name__ == "__main__":
    country_name = country()
    usd_new_data = []
    jpy_new_data = []
    eur_new_data = []
    cny_new_data = []
    cad_new_data = []
    aud_new_data = []
    
    usd_new_data = usd_get_one_data(country_name[0])
    jpy_new_data = jpy_get_one_data(country_name[1])
    eur_new_data = eur_get_one_data(country_name[2])
    cny_new_data = cny_get_one_data(country_name[3])
    cad_new_data = cad_get_one_data(country_name[4])
    aud_new_data = aud_get_one_data(country_name[5])
    print(usd_new_data)
    print(jpy_new_data)
    print(eur_new_data)
    print(cny_new_data)
    print(cad_new_data)
    print(aud_new_data)

    toCSV_a(usd_new_data)
    toCSV_b(jpy_new_data)
    toCSV_b(eur_new_data)
    toCSV_b(cny_new_data)
    toCSV_b(cad_new_data)
    toCSV_b(aud_new_data)
# Out:
# ['USA', '2019.12.04', '1193.00', '1213.87', '1172.13', '1204.60', '1181.40', '1207.31', '1180.23']
# ['JAPAN', '2019.12.04', '1097.97', '1117.18', '1078.76', '1108.73', '1087.21', '1108.94', '1086.73']
# ['EUROPE', '2019.12.04', '1321.37', '1347.66', '1295.08', '1334.58', '1308.16', '1341.19', '1307.63']
# ['CHINA', '2019.12.04', '169.07', '177.52', '160.62', '170.76', '167.38', 'N/A', 'N/A']
# ['CANADA', '2019.12.04', '898.21', '915.90', '880.52', '907.19', '889.23', '911.68', '888.24']
# ['AUSTRALIA', '2019.12.04', '814.88', '830.93', '798.83', '823.02', '806.74', '827.10', '805.93']
